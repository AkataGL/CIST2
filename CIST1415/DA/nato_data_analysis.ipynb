# %%
import pandas as pd

# %%
df = pd.read_csv('SIPRI-Milex-data-1949-2022-copy2.csv', encoding = "utf-8")

df
# Out:
#                      Country   1949   1950    1951    1952    1953    1954  \
# 0                     Canada    ...  2.43%   4.66%   6.80%   7.37%   6.86%
# 1   United States of America  5.27%  5.08%  10.17%  13.86%  13.58%  11.74%
# 2                      India    ...    ...     ...     ...     ...     ...
# 3                      China    ...    ...     ...     ...     ...     ...
# 4                    Albania    ...    ...     ...     ...     ...     ...
# 5                   Bulgaria    ...    ...     ...     ...     ...     ...
# 6                    Croatia    ...    ...     ...     ...     ...     ...
# 7                    Czechia    ...    ...     ...     ...     ...     ...
# 8                    Estonia    ...    ...     ...     ...     ...     ...
# 9                    Hungary    ...    ...     ...     ...     ...     ...
# 10                    Latvia    ...    ...     ...     ...     ...     ...
# ...

# %%
df.set_index('Country').transpose()
# Out:
# Country Canada United States of America  India  China Albania Bulgaria  \
# 1949       ...                    5.27%    ...    ...     ...      ...
# 1950     2.43%                    5.08%    ...    ...     ...      ...
# 1951     4.66%                   10.17%    ...    ...     ...      ...
# 1952     6.80%                   13.86%    ...    ...     ...      ...
# 1953     7.37%                   13.58%    ...    ...     ...      ...
# ...        ...                      ...    ...    ...     ...      ...
# 2017     1.35%                    3.31%  2.53%  1.75%   1.11%    1.23%
# 2018     1.32%                    3.31%  2.43%  1.74%   1.16%    1.45%
# 2019     1.29%                    3.43%  2.52%  1.73%   1.30%    3.15%
# 2020     1.42%                    3.72%  2.88%  1.80%   1.26%    1.54%
# 2021     1.32%                    3.48%  2.66%  1.74%   1.42%    1.59%
#
# Country Croatia Czechia Estonia Hungary  ... Greece Iceland  Italy Luxembourg  \
# ...

# %%
df.columns
# Out:
# Index(['Country', '1949', '1950', '1951', '1952', '1953', '1954', '1955',
#        '1956', '1957', '1958', '1959', '1960', '1961', '1962', '1963', '1964',
#        '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973',
#        '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982',
#        '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991',
#        '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000',
#        '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009',
#        '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018',
#        '2019', '2020', '2021'],
#       dtype='object')

# %%
df.shape
# Out:
# (34, 74)

# %%
df.columns
# Out:
# Index(['Country', '1949', '1950', '1951', '1952', '1953', '1954', '1955',
#        '1956', '1957', '1958', '1959', '1960', '1961', '1962', '1963', '1964',
#        '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973',
#        '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982',
#        '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991',
#        '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000',
#        '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009',
#        '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018',
#        '2019', '2020', '2021'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173 entries, 0 to 172
# Data columns (total 74 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Country  173 non-null    object
#  1   1949     173 non-null    object
#  2   1950     173 non-null    object
#  3   1951     173 non-null    object
#  4   1952     173 non-null    object
#  5   1953     173 non-null    object
#  6   1954     173 non-null    object
#  7   1955     173 non-null    object
#  8   1956     173 non-null    object
#  9   1957     173 non-null    object
#  10  1958     173 non-null    object
#  11  1959     173 non-null    object
#  12  1960     173 non-null    object
#  13  1961     173 non-null    object
#  14  1962     173 non-null    object
#  15  1963     173 non-null    object
#  16  1964     173 non-null    object
#  17  1965     173 non-null    object
#  18  1966     173 non-null    object
#  19  1967     173 non-null    object
# ...

# %%
df.isna().sum()
# Out:
#